# %%
#%env HF_TOKEN=hf_XXX
# Now uses ollama, make sure you have it running and a good model to use.

# %%
from smolagents import CodeAgent, LiteLLMModel
import os

model = LiteLLMModel(model_id="ollama_chat/qwen3.5")

model

# %%
from smolagents import CodeAgent, LiteLLMModel

llama_model = LiteLLMModel(model_id="ollama_chat/qwen3.5")

agent = CodeAgent(tools=[], model=llama_model, add_base_tools=True)

agent.run(
    "Could you give me the 118th number in the Fibonacci sequence?",
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Could you give me the 118th number in the Fibonacci sequence?                                                   │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen3.5 ────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   def fibonacci(n):
#       if n == 0:
#           return 0
#       elif n == 1:
#           return 1
#
#       a, b = 0, 1
#       for i in range(2, n + 1):
#           a, b = b, a + b
#       return b
#
#   fib_118 = fibonacci(118)
#   print(f"The 118th Fibonacci number is: {fib_118}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# The 118th Fibonacci number is: 2046711111473984623691759
#
# Out: None
# [Step 1: Duration 11.28 seconds| Input tokens: 2,261 | Output tokens: 303]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("204671111473984623691759")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 204671111473984623691759
# [Step 2: Duration 5.86 seconds| Input tokens: 4,903 | Output tokens: 450]
# '204671111473984623691759'

# %% [markdown]
# ## Claude
# <img src="../images/claudefib.png" alt="Claude Screenshot" width="400"/>

# %% [markdown]
# ## OpenAI
# <img src="../images/openaifib.png" alt="OpenAI Screenshot" width="400"/>

# %% [markdown]
# ## DeepSeek
# <img src="../images/deepseekfib.png" alt="DeepSeek Screenshot" width="400"/>

# %%
# Llama said 1,264,937,032,042,997,393,488,322
# OpenAI said 2,046,711,111,473,984,623,691,759
# Claude said 4,224,696,333,392,220,272,978,344,770,991,272,720,046,789
# DeepSeek gave code that yields 2,046,711,111,473,984,623,691,759 but then SAID 3,311,648,143,516,982,017,180,081

# sooo who's right? Your homework is to figure out who ;) 
#  Hint, assumptions are being made and the AI's disagree on what assumption to make.

# %%
agent.run("Could you get me the title of the page at url 'https://huggingface.co/blog'?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Could you get me the title of the page at url 'https://huggingface.co/blog'?                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen3.5 ────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url = 'https://huggingface.co/blog'
#   content = visit_webpage(url)
#   print(content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'content = visit_webpage(url)' due to: ImportError: You must install packages
# `markdownify` and `requests` to run this tool: for instance run `pip install markdownify requests`.
# [Step 1: Duration 5.48 seconds| Input tokens: 2,265 | Output tokens: 145]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url = 'https://huggingface.co/blog'
#   try:
#       content = visit_webpage(url)
#       print(content)
#   except Exception as e:
#       print(f"Error: {e}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Error: You must install packages `markdownify` and `requests` to run this tool: for instance run `pip install
# markdownify requests`.
#
# Out: None
# [Step 2: Duration 9.93 seconds| Input tokens: 4,753 | Output tokens: 495]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = web_search(query="https://huggingface.co/blog page title")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [GitHub - huggingface/blog: Public repo for HF blog postsGitHub - ego/huggingface-blog: Public repo for HF blog
# posts ...blog/README.md at main · huggingface/blog · GitHubHugging Face – The AI community building the future.Blog
# System Architecture | huggingface/blog | DeepWikiGetting Started With Hugging Face in 10
# Minutes](https://github.com/huggingface/blog)
# This is the official repository of the Hugging FaceBlog.If you are an external contributor: If yourblogpost is not
# a collaboration post with Hugging Face, please consider creating a communitybloginstead. Communityblogposts appear
# on our blogs mainpagejust like the blogs in this repository.See full list on github.com1️⃣ Create a branch
# YourName/Title2️⃣ Create a md (markdown) file, use a short file name. For instance, if yourtitleis "Introduction to
# Deep Reinforcement Learning", the md file name could be intro-rl.md. This is important because the file name will
# be the blogpost's URL.3️⃣ Create a new folder in assets. Use the same name as the name of the md file. Optionally
# you may add a numerical prefix to that folder, using the number that hasn't been used yet. But this is no longer
# required. i.e. the asset folder in this example could be 123_intro-rl or intro-rl. This folder will contain your
# thumbnail only. The folder number is mostly for (rough) ordering purposes, so it's no big deal if two concurrent
# articles use the same number.For the rest of your files, create a mirrored folder in theHuggingFaceDocumentation
# Images repo. This is to reduce bloat in the GitHub base repo when cloning and pulling.🖼️: In terms of images, try
# to have small files to avoid having a slow loading user experience:•Use compressed images, you can use this
# website:https://tinypng.com orhttps://www.iloveimg.com/compress-imageSee full list on github.com1️⃣ Create a
# 1300x650 image2️⃣ Use this template and fill the content part.See full list on github.comThis is the official
# repository of the Hugging FaceBlog. If you are an external contributor: If yourblogpost is not a collaboration post
# with Hugging Face, please consider creating a community blog instead.This is the official repository of the Hugging
# FaceBlog. If you are an external contributor: If yourblogpost is not a collaboration post with Hugging Face, please
# consider creating a community blog instead. Communityblogposts appear on our blogs main page just like the blogs in
# this repository. 1️⃣ Create a branch YourName/Title.Access 45,000+ models from leading AI providers through a
# single, unified API with no service fees. Deploy on optimized Inference Endpoints or update your Spaces
# applications to a GPU in a few clicks. We are building the foundation of ML tooling with the community.Nov 13, 2025
# ·This document describes the technical architecture of the Hugging Faceblogcontent management system, including the
# file-based structure, metadata organization, asset management, and publication workflow.Mar 10, 2025 ·In this
# article, I’ll introduce Hugging Face — a company that provides tools and platforms for building machine learning
# applications. We’ll explore what Hugging Face offers, how to use its resources, and how it’s transforming the field
# of artificial intelligence.
#
# [GitHub - ego/huggingface-blog: Public repo for HF blog posts ...](https://github.com/ego/huggingface-blog)
# This is the official repository of the Hugging FaceBlog. If you are an external contributor: If yourblogpost is not
# a collaboration post with Hugging Face, please consider creating a community blog instead.
#
# [blog/README.md at main · huggingface/blog · GitHub](https://github.com/huggingface/blog/blob/main/README.md)
# This is the official repository of the Hugging FaceBlog. If you are an external contributor: If yourblogpost is not
# a collaboration post with Hugging Face, please consider creating a community blog instead. Communityblogposts
# appear on our blogs main page just like the blogs in this repository. 1️⃣ Create a branch YourName/Title.
#
# [Blog System Architecture | huggingface/blog |
# DeepWiki](https://deepwiki.com/huggingface/blog/1.1-blog-system-architecture)
# Nov 13, 2025 ·This document describes the technical architecture of the Hugging Faceblogcontent management system,
# including the file-based structure, metadata organization, asset management, and publication workflow.
#
# [HuggingFace- Current Openings](https://apply.workable.com/huggingface/)
# AtHuggingFace, we build open-source resources to empower you to easily integrate AI into your products and
# workflows.Here atHuggingFace, we’re on a journey to advance and democratize ML for everyone. Along the way, we
# contribute to the development of technology for the better.
#
# [HuggingFace: где искать ИИ-модели](https://vc.ru/ai/1838000-hugging-face-gde-iskat-besplatnye-neiroseti)
# HuggingFace— платформа с тысячами бесплатных ИИ-моделей для генерации текста, изображений, аудио и видео.
#
# [GitHub -huggingface/transformers: Transformers: the...](https://github.com/huggingface/transformers)
# There are over 1M+ Transformers model checkpoints on theHuggingFaceHub you can use. Explore the Hub today to find a
# model and use Transformers to help you get started right away. Installation.
#
# [ExploringHuggingFace: An Introduction | by Okan Yenigün](https://freedium-mirror.cfd/0fee3c59e307)
# huggingface.co.HuggingFacebegan its journey as a quirky chatbotcompany, kind of like that cool, friendly robot
# you'd want to hang out with. But as they delved deeper into the world of AI, they hit upon something big — the
# Transformers library. This was like striking gold in the AI universe!
#
# [HuggingFace| LinkedIn](https://www.linkedin.com/company/huggingface)
# HuggingFace. Natural Language Processing (NLP) Software. We’re on a journey to solve and democratize artificial
# intelligence through natural language.HuggingFacereposted this. View organizationpagefor Gradio.
#
# [Hugging Face – Blog](https://huggingface.co/blog)
# ... We’re on a journey to advance and democratize artificial intelligence through open source and open science.
#
# Out: None
# [Step 3: Duration 8.75 seconds| Input tokens: 7,482 | Output tokens: 666]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = web_search(query="site:huggingface.co/blog page title")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [LightOnOCR-1B: The Case for End-to-End and Efficient Domain-Specific
# ...](https://huggingface.co/blog/lightonai/lightonocr)
# A Blog post by LightOn AI on Hugging Face
#
# [In-Depth Analysis of the Latest Deep Research Technology: Cutting-Edge
# ...](https://huggingface.co/blog/exploding-gradients/deepresearch-survey)
# A Blog post by Exploding Gradients on Hugging Face
#
# [ViDoRe Benchmark V2: Raising the Bar for Visual Retrieval](https://huggingface.co/blog/manu/vidore-v2)
# Visual Document Retrieval Benchmark 3 leaderboard. To submit results, refer to the corresponding tab. Refer to: 🤗
# The blogpost for all the details on the datasets, 🤗 The dataset collection, 📝 The ColPali paper for details on
# metrics.
#
# [The AI Paradigm Shift Is Here: 4 Disruptive Trends from the Top 50
# ...](https://huggingface.co/blog/vansin/hf-papers-25q3-top50)
# A Blog post by vansin on Hugging Face
#
# [The World's First Public Diffusion Model ... - Hugging
# Face](https://huggingface.co/blog/ytmack7/diffusion-model-leaderboard)
# A Blog post by Mackenzie Derival on Hugging Face
#
# [Little Paper Reviews & AutoCodeRover - Hugging Face](https://huggingface.co/blog/tiginamaria/papers)
# A Blog post by Maria Tigina on Hugging Face
#
# [SmolLM3: smol, multilingual, long-context reasoner](https://huggingface.co/blog/smollm3)
# Congratulations to the team on the release of SmolLM3! This is a really impressive piece of work, and the detailed
# ablations on GQA, NoPE, and the other architectural tweaks are super valuable for the community. Your focus on
# pushing the boundaries of long-context performance is fascinating. It reminded me of a recent paper that tackles
# the same challenge from a completely different ...
#
# [Welcome to the Falcon 3 Family of Open Models! - Hugging Face](https://huggingface.co/blog/falcon3)
# We're on a journey to advance and democratize artificial intelligence through open source and open science.
#
# [The Past and Present of Sparse Retrieval - Hugging
# Face](https://huggingface.co/blog/yjoonjang/the-past-and-present-of-sparse-retrieval)
# Sparse retrieval has quietly powered search for decades, and it's having a renaissance alongside dense embeddings.
# This article walks through where sparse methods came from, how they evolved, and why they still matter. 1. TF-IDF,
# BM25, Indexing 1-1. TF-IDF TF-IDF (Term Frequency-Inverse Document Frequency) assigns importance to words using
# their Term Frequency (TF) and Inverse Document ...
#
# [FineVideo: behind the scenes - Hugging Face](https://huggingface.co/blog/fine-video)
# Code for content filtering and metadata gathering available here [link] Downloading the videos Once we had a target
# video list with 1.9M videos, we managed to successfully download 1.8M videos (some of the videos where removed by
# the channel owners and some changed their permissions). We explored two different approaches for distributed
# downloading. Option 1: Video2dataset video2dataset is an ...
#
# Out: None
# [Step 4: Duration 9.14 seconds| Input tokens: 11,784 | Output tokens: 863]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = web_search(query="\"Hugging Face – Blog\" site:huggingface.co")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [HuggingFace–Blog](https://huggingface.co/blog)
# HuggingFace's logoHuggingFace. Models. Datasets.February 20, 2026. llmfine-tuningtraining. Train AI models with
# Unsloth andHuggingFaceJobs for FREE.
#
# [HuggingFace–Blog](https://huggingface.co/blog?sort=desc)
# HuggingFace's logoHuggingFace. Models. Datasets.By January 19, 2021. Faster TensorFlow models
# inHuggingFaceTransformers.
#
# [HuggingFace– Posts](https://huggingface.co/posts)
# HuggingFace's logoHuggingFace. Models. Datasets. We release all produced benchmarks onHuggingFacetogether with the
# source code and Arxiv paper.
#
# [HuggingFaceBlogAssistant - aHuggingFaceSpace
# by...](https://huggingface.co/spaces/derek-thomas/hugging-face-blog-assistant)
# Easily add formatted snippets like image tables, tip formats, and references to yourblogposts. See your changes in
# real-time with the live preview.HuggingFace's logo. derek-thomas.
#
# [Getting Started With Hugging Face in 10 Minutes](https://huggingface.co/blog/proflead/hugging-face-tutorial)
# Mar 10, 2025 ·ABlogpost by Vladislav Guzey onHugging Face
#
# [Hugging Face – Community Blogs](https://huggingface.co/blog/community)
# We’re on a journey to advance and democratize artificial intelligence through open source and open science.
#
# [Hugging Face – The AI community building the future.](https://huggingface.co/)
# We’re on a journey to advance and democratize artificial intelligence through open source and open science.
#
# [Generate Images with Claude and Hugging Face](https://huggingface.co/blog/claude-and-mcp)
# Aug 19, 2025 ·We’re on a journey to advance and democratize artificial intelligence through open source and open
# science.
#
# [Hugging Face – Posts](https://huggingface.co/Posts)
# Share and discover more about AI with social posts from the community.
#
# [Stable Diffusion with Diffusers](https://huggingface.co/blog/stable_diffusion)
# HuggingFace's logoHuggingFace.The Getting Started with Diffusers notebook, that gives a broader overview on
# Diffusion systems. The Annotated Diffusion Modelblogpost.
#
# Out: None
# [Step 5: Duration 7.61 seconds| Input tokens: 16,986 | Output tokens: 983]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("HuggingFace–Blog")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: HuggingFace–Blog
# [Step 6: Duration 5.00 seconds| Input tokens: 22,871 | Output tokens: 1,124]
# 'HuggingFace–Blog'

# %% [markdown]
# THe rest of this requires hugging face token with inference permsions

# %%
from smolagents import Tool
from IPython.display import Image, display

image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

image_generation_tool("A sunny beach")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 from smolagents import Tool
#       2 from IPython.display import Image, display
# ----> 4 image_generation_tool = Tool.from_space(
#       5     "black-forest-labs/FLUX.1-schnell",
#       6     name="image_generator",
#       7     description="Generate an image from a prompt"
#       8 )
#      10 image_generation_tool("A sunny beach")
#
# File ~/devel/oreilly-ai-agents/.venv/lib/python3.12/site-packages/smolagents/tools.py:733, in Tool.from_space(space_id, name, description, api_name, token)
#     730             output = AgentAudio(output)
#     731         return output
# --> 733 return SpaceToolWrapper(
#     734     space_id=space_id,
#     735     name=name,
#     736     description=description,
#     737     api_name=api_name,
#     738     token=token,
#     739 )
#
# File ~/devel/oreilly-ai-agents/.venv/lib/python3.12/site-packages/smolagents/tools.py:75, in validate_after_init.<locals>.new_init(self, *args, **kwargs)
#      73 @wraps(original_init)
#      74 def new_init(self, *args, **kwargs):
# ---> 75     original_init(self, *args, **kwargs)
#      76     self.validate_arguments()
#
# File ~/devel/oreilly-ai-agents/.venv/lib/python3.12/site-packages/smolagents/tools.py:658, in Tool.from_space.<locals>.SpaceToolWrapper.__init__(self, space_id, name, description, api_name, token)
#     656 self.name = name
#     657 self.description = description
# --> 658 self.client = Client(space_id, hf_token=token)
#     659 space_api = self.client.view_api(return_format="dict", print_info=False)
#     660 assert isinstance(space_api, dict)
#
# TypeError: Client.__init__() got an unexpected keyword argument 'hf_token'

# %%
agent = CodeAgent(tools=[image_generation_tool], model=llama_model, add_base_tools=True)  # base tools include duckduckgo

agent.run(
    "Look up the weather in SF today, describe it and draw an image based on it",
)

# %%
from IPython.display import Image, display

display(Image(filename='/private/var/folders/y9/9xqbqkg90tnc0cmm0dxt985m0000gn/T/gradio/cc514ca315cb91a3d754089fe97943cf17495d88416707e0b9b528c5b812a152/image.webp'))
